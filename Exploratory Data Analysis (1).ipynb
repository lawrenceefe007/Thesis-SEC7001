# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
from pylab import rcParams

# %%
# imorting the dataset
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-07-26   48.652500   48.990002   48.402500   48.552502   46.400436
# 1    2018-07-27   48.747501   48.797501   47.525002   47.744999   45.628712
# 2    2018-07-30   47.974998   48.049999   47.267502   47.477501   45.373081
# 3    2018-07-31   47.575001   48.035000   47.334999   47.572498   45.463867
# 4    2018-08-01   49.782501   50.439999   49.327499   50.375000   48.142139
# ...         ...         ...         ...         ...         ...         ...
# 1252 2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 1253 2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
# 1254 2023-07-21  194.100006  194.970001  191.229996  191.940002  191.940002
# 1255 2023-07-24  193.410004  194.910004  192.250000  192.750000  192.750000
# 1256 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
#
#          Volume
# 0      76304000
# 1      96096000
# ...

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2018-07-26  48.652500  48.990002  48.402500  48.552502  46.400436   76304000
# 1 2018-07-27  48.747501  48.797501  47.525002  47.744999  45.628712   96096000
# 2 2018-07-30  47.974998  48.049999  47.267502  47.477501  45.373081   84118000
# 3 2018-07-31  47.575001  48.035000  47.334999  47.572498  45.463867  157492000
# 4 2018-08-01  49.782501  50.439999  49.327499  50.375000  48.142139  271742800

# %%
# Display the last 5 rows of the DataFrame
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1252 2023-07-19  193.100006  198.229996  192.649994  195.100006  195.100006
# 1253 2023-07-20  195.089996  196.470001  192.500000  193.130005  193.130005
# 1254 2023-07-21  194.100006  194.970001  191.229996  191.940002  191.940002
# 1255 2023-07-24  193.410004  194.910004  192.250000  192.750000  192.750000
# 1256 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
#
#         Volume
# 1252  80507300
# 1253  59581200
# 1254  71917800
# 1255  45377800
# 1256  37184800

# %%
# Check for null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Check the structure of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1257 non-null   datetime64[ns]
#  1   Open       1257 non-null   float64
#  2   High       1257 non-null   float64
#  3   Low        1257 non-null   float64
#  4   Close      1257 non-null   float64
#  5   Adj Close  1257 non-null   float64
#  6   Volume     1257 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
# Check the data types of each column
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# Print the shape of the DataFrame
df.shape
# Out:
# (1257, 7)

# %%
#checking the duration of the dataset

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Calculate the duration of the dataset
duration = df.index.max() - df.index.min()

print('Duration of dataset:', duration)
# Out:
# Duration of dataset: 1825 days 00:00:00

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean    111.409406   112.746595   110.171221   111.521740   110.179415
# std      46.543477    47.066250    46.064595    46.589828    46.910935
# min      35.994999    36.430000    35.500000    35.547501    34.209961
# 25%      59.942501    60.810001    59.224998    60.127499    58.558697
# 50%     125.019997   126.442497   123.849998   125.059998   123.611450
# 75%     149.360001   151.179993   147.830002   149.699997   148.691528
# max     195.089996   198.229996   192.919998   195.100006   195.100006
#
#              Volume
# count  1.257000e+03
# mean   1.099083e+08
# std    5.501639e+07
# min    3.145820e+07
# 25%    7.442020e+07
# 50%    9.528000e+07
# 75%    1.295540e+08
# max    4.265100e+08

# %%
#plotting stock price over time

# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Plot the data
plt.figure(figsize=(18,9))
plt.plot(df['Open'], label='Open')
plt.plot(df['Close'], label='Close')
plt.plot(df['High'], label='High')
plt.plot(df['Low'], label='Low')


plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
#histogram of daily price changes

# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Calculate the daily price change
df['Price Change'] = df['Close'] - df['Open']

# Plot the histogram
plt.figure(figsize=(14, 8))
plt.hist(df['Price Change'], bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Daily Price Changes')
plt.xlabel('Price Change')
plt.ylabel('Frequency')
plt.show()

# %%
#stock volume over time

# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Plot the volume data
plt.figure(figsize=(14,7))
plt.bar(df.index, df['Volume'], color='blue')

plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
#stock closing prices and moving averages


# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Calculate the moving averages
df['7 Day Avg'] = df['Close'].rolling(window=7).mean()
df['30 Day Avg'] = df['Close'].rolling(window=30).mean()

# Plot the closing prices and moving averages
plt.figure(figsize=(18,9))
plt.plot(df['Close'], label='Close')
plt.plot(df['7 Day Avg'], label='7 Day Average', linestyle='--')
plt.plot(df['30 Day Avg'], label='30 Day Average', linestyle='--')

plt.title('Stock Closing Prices and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
#monthly comparison of stock open and close prices


# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Resample the data to a monthly frequency
monthly_df = df.resample('M').mean()

# Plot the monthly open and close prices
plt.figure(figsize=(14,7))
plt.plot(monthly_df['Open'], label='Open', marker='o' , color='red')
plt.plot(monthly_df['Close'], label='Close', marker='o' , color='green')

plt.title('Monthly Comparison of Stock Open and Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
#monthly comparison of stock high and low prices


# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Resample the data to a monthly frequency
monthly_df = df.resample('M').mean()

# Plot the monthly high and low prices
plt.figure(figsize=(14,7))
plt.plot(monthly_df['High'], label='High', marker='o' , color='red')
plt.plot(monthly_df['Low'], label='Low', marker='o' , color='green')

plt.title('Monthly Comparison of Stock High and Low Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Create a boxplot of the stock prices by year
plt.figure(figsize=(25,8))
sns.boxplot(x=df.index.year, y=df['Close'])
plt.title('Stock Close Price Yearly')
plt.xlabel('Year')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# Read the CSV data into a pandas DataFrame
df = pd.read_csv("C:\\Users\\lefen\\Downloads\\AAPL.csv", parse_dates=['Date'], dayfirst=True)

# Set the Date column as the index of the DataFrame
df.set_index('Date', inplace=True)

# Create a boxplot of the stock prices by month
fig, ax = plt.subplots(figsize=(22,8))
sns.boxplot(x = df.index.month_name(), y=df['Close'], ax=ax)  
plt.title('Stock Price by Month')
plt.xlabel('Month')
plt.ylabel('Price')
plt.show()
